# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
org_file = "10-second-count-down.wav"  # your generated output
y, sr = librosa.load(org_file, sr=None)

plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Original Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %%
output_file = "scaled.wav"  # your generated output
y, sr = librosa.load(output_file, sr=None)

plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Scaled Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %%
output_file = "reflected.wav"  # your generated output
y, sr = librosa.load(output_file, sr=None)

plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Reflected Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %%
output_file = "reversed.wav"
y, sr = librosa.load(output_file, sr=None)

plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Reversed Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %%
output_file = "filtered.wav"
y, sr = librosa.load(output_file, sr=None)

plt.figure(figsize=(12, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Filtered Waveform")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()
